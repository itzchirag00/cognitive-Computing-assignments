# %%
import numpy as np
import pandas as pd

np.random.seed(102317142)

sales_data = np.random.randint(1000, 5001, size=(12, 4))

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
df_sales = pd.DataFrame(sales_data, columns=categories, index=months)

df_sales
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4364      1452            1562    2754
# Feb         4840      1329            3474    3427
# Mar         2871      2022            3109    4819
# Apr         4321      1544            3773    2190
# May         1199      2987            1585    4091
# Jun         1166      1268            1822    4020
# Jul         2737      2070            3109    4169
# Aug         2133      1533            4621    3188
# Sep         2816      2376            1658    4398
# Oct         4075      4332            4814    4518
# Nov         3260      4988            4437    2745
# Dec         2746      1575            3164    4987

# %%
rows = df_sales.head()
print('Top 5 Rows')
print(rows)
print('\n')
stats = df_sales.describe()
print(stats)
print('\n')

totalcategory = df_sales.sum()
print(totalcategory)
print('\n')
totalmonth = df_sales.sum(axis=1)
print(totalmonth)
print('\n')

averagesales = df_sales.pct_change().mean()
print(averagesales)

df_sales['Total Sales'] = df_sales.sum(axis=1)
df_sales['Growth Rate'] = df_sales['Total Sales'].pct_change() * 100
print(df_sales)

roll_number = 102317142

if roll_number % 2 == 0:
    df_sales['Electronics'] = df_sales['Electronics'] * 0.9
else:
    df_sales['Clothing'] = df_sales['Clothing'] * 0.85

df_sales
# Out:
# Top 5 Rows
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4364      1452            1562    2754
# Feb         4840      1329            3474    3427
# Mar         2871      2022            3109    4819
# Apr         4321      1544            3773    2190
# May         1199      2987            1585    4091
#
#
#        Electronics     Clothing  Home & Kitchen      Sports
# count    12.000000    12.000000       12.000000    12.00000
# mean   3044.000000  2289.666667     3094.000000  3775.50000
# std    1195.984114  1220.038549     1206.375262   899.26288
# min    1166.000000  1268.000000     1562.000000  2190.00000
# 25%    2586.000000  1512.750000     1781.000000  3079.50000
# 50%    2843.500000  1798.500000     3136.500000  4055.50000
# 75%    4136.500000  2528.750000     3939.000000  4428.00000
# max    4840.000000  4988.000000     4814.000000  4987.00000
#
#
# Electronics       36528
# Clothing          27476
# Home & Kitchen    37128
# Sports            45306
# dtype: int64
#
#
# Jan    10132
# Feb    13070
# Mar    12821
# Apr    11828
# May     9862
# Jun     8276
# Jul    12085
# Aug    11475
# Sep    11248
# Oct    17739
# Nov    15430
# Dec    12472
# dtype: int64
#
#
# Electronics       0.090323
# Clothing          0.161166
# Home & Kitchen    0.271997
# Sports            0.144419
# dtype: float64
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         4364      1452            1562    2754        10132          NaN
# Feb         4840      1329            3474    3427        13070    28.997236
# Mar         2871      2022            3109    4819        12821    -1.905126
# Apr         4321      1544            3773    2190        11828    -7.745106
# May         1199      2987            1585    4091         9862   -16.621576
# Jun         1166      1268            1822    4020         8276   -16.081931
# Jul         2737      2070            3109    4169        12085    46.024650
# Aug         2133      1533            4621    3188        11475    -5.047580
# Sep         2816      2376            1658    4398        11248    -1.978214
# Oct         4075      4332            4814    4518        17739    57.708037
# Nov         3260      4988            4437    2745        15430   -13.016517
# Dec         2746      1575            3164    4987        12472   -19.170447
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       3927.6      1452            1562    2754        10132          NaN
# Feb       4356.0      1329            3474    3427        13070    28.997236
# Mar       2583.9      2022            3109    4819        12821    -1.905126
# Apr       3888.9      1544            3773    2190        11828    -7.745106
# May       1079.1      2987            1585    4091         9862   -16.621576
# Jun       1049.4      1268            1822    4020         8276   -16.081931
# Jul       2463.3      2070            3109    4169        12085    46.024650
# Aug       1919.7      1533            4621    3188        11475    -5.047580
# Sep       2534.4      2376            1658    4398        11248    -1.978214
# Oct       3667.5      4332            4814    4518        17739    57.708037
# Nov       2934.0      4988            4437    2745        15430   -13.016517
# Dec       2471.4      1575            3164    4987        12472   -19.170447

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
for category in categories:
    plt.plot(df_sales.index, df_sales[category], marker='o', label=category)
plt.title('Monthly Sales Trends for Each Category')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_sales[categories])
plt.title('Sales Distribution for Each Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
import numpy as np

array = np.array([[1, -2, 3], [-4, 5, -6]])

abs_array = np.abs(array)

flattened_array = array.flatten()
percentiles_flattened = np.percentile(flattened_array, [25, 50, 75])
percentiles_columns = np.percentile(array, [25, 50, 75], axis=0)
percentiles_rows = np.percentile(array, [25, 50, 75], axis=1)

mean_flattened = np.mean(flattened_array)
mean_columns = np.mean(array, axis=0)
mean_rows = np.mean(array, axis=1)

median_flattened = np.median(flattened_array)
median_columns = np.median(array, axis=0)
median_rows = np.median(array, axis=1)

std_flattened = np.std(flattened_array)
std_columns = np.std(array, axis=0)
std_rows = np.std(array, axis=1)

print(abs_array,
 percentiles_flattened,
 percentiles_columns,
 percentiles_rows,
 mean_flattened,
 mean_columns,
 mean_rows,
 median_flattened,
 median_columns,
 median_rows,
 std_flattened,
 std_columns,
 std_rows)
# Out:
# [[1 2 3]
#  [4 5 6]] [-3.5 -0.5  2.5] [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]] [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]] -0.5 [-1.5  1.5 -1.5] [ 0.66666667 -1.66666667] -0.5 [-1.5  1.5 -1.5] [ 1. -4.] 3.8622100754188224 [2.5 3.5 4.5] [2.05480467 4.78423336]

# %%
import numpy as np

a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])

floor_values = np.floor(a)

ceiling_values = np.ceil(a)
truncated_values = np.trunc(a)

rounded_values = np.round(a)

print(floor_values, ceiling_values, truncated_values, rounded_values)
# Out:
# [-2. -2. -1.  0.  1.  1.  3.] [-1. -1. -0.  1.  2.  2.  3.] [-1. -1. -0.  0.  1.  1.  3.] [-2. -2. -0.  0.  2.  2.  3.]

# %%
def swap_elements(lst, i, j):
    temp = lst[i]
    lst[i] = lst[j]
    lst[j] = temp
list1 = [1, 2, 3, 4, 5]
print("Original list:", list1)

swap_elements(list1, 1, 3)
print("List after swapping elements at indices 1 and 3:", list1)
# Out:
# Original list: [1, 2, 3, 4, 5]
# List after swapping elements at indices 1 and 3: [1, 4, 3, 2, 5]

# %%
def swap(s, e1, e2):

    lst1 = list(s)

    i1 = lst1.index(e1)
    i2 = lst1.index(e2)

    temp = lst1[i1]
    lst1[i1] = lst1[i2]
    lst1[i2] = temp

    swapped_set = set(lst1)
    return swapped_set

set1 = {1, 2, 3, 4, 5}
print("Original set:", set1)

swapped_set = swap(set1, 2, 4)
print("Set after swapping elements 2 and 4:", set1)
# Out:
# Original set: {1, 2, 3, 4, 5}
# Set after swapping elements 2 and 4: {1, 2, 3, 4, 5}
